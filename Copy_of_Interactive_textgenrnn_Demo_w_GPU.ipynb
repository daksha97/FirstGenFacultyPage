# %% [markdown]
# <a href="https://colab.research.google.com/github/daksha97/FirstGenFacultyPage/blob/master/Copy_of_Interactive_textgenrnn_Demo_w_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Interactive textgenrnn Demo w/ GPU
#
# by [Max Woolf](http://minimaxir.com)
#
# *Last updated: December 2nd, 2018*
#
# Generate text using a pretrained neural network with a few lines of code, or easily train your own text-generating neural network of any size and complexity, **for free on a GPU using Collaboratory!**
#
# For more about textgenrnn, you can visit [this GitHub repository](https://github.com/minimaxir/textgenrnn).
#
#
# To get started:
#
# 1. Copy this notebook to your Google Drive to keep it and save your changes.
# 2. Make sure you're running the notebook in Google Chrome.
# 3. Run the cells below:

# %%
# !pip install -q textgenrnn
from google.colab import files
from textgenrnn import textgenrnn
from datetime import datetime
import os

# %% [markdown]
# Set the textgenrnn model configuration here: the default parameters here give good results for most workflows. (see the [demo notebook](https://github.com/minimaxir/textgenrnn/blob/master/docs/textgenrnn-demo.ipynb) for more information about these parameters)
#
# If you are using an input file where documents are line-delimited, make sure to set `line_delimited` to `True`.

# %%
model_cfg = {
    'word_level': True,   # set to True if want to train a word-level model (requires more data and smaller max_length)
    'rnn_size': 128,   # number of LSTM cells of each layer (128/256 recommended)
    'rnn_layers': 3,   # number of LSTM layers (>=2 recommended)
    'rnn_bidirectional': True,   # consider text both forwards and backward, can give a training boost
    'max_length': 7,   # number of tokens to consider before predicting the next (20-40 for characters, 5-10 for words recommended)
    'max_words': 10000,   # maximum number of words to model; the rest will be ignored (word-level model only)
}

train_cfg = {
    'line_delimited': False,   # set to True if each text has its own line in the source file
    'num_epochs': 20,   # set higher to train the model for longer
    'gen_epochs': 5,   # generates sample text from model after given number of epochs
    'train_size': 0.8,   # proportion of input data to train on: setting < 1.0 limits model from learning perfectly
    'dropout': 0.0,   # ignore a random proportion of source tokens each epoch, allowing model to generalize better
    'validation': False,   # If train__size < 1.0, test on holdout dataset; will make overall training slower
    'is_csv': False   # set to True if file is a CSV exported from Excel/BigQuery/pandas
}

# %% [markdown]
# In the Colaboratory Notebook sidebar on the left of the screen, select *Files*. From there you can upload files:
#
# ![alt text](https://i.imgur.com/TGcZT4h.png)
#
# Upload **any text file** and update the file name in the cell below, then run the cell.

# %%
file_name = "train.txt"
model_name = 'colaboratory'   # change to set file name of resulting trained models/texts

# %% [markdown]
# The next cell will start the actual training. And thanks to the power of Keras's CuDNN layers, training is super-fast when compared to CPU training on a local machine!
#
# Ideally, you want a training loss less than `1.0` in order for the model to create sensible text consistently.

# %%
textgen = textgenrnn(name=model_name)

train_function = textgen.train_from_file if train_cfg['line_delimited'] else textgen.train_from_largetext_file

train_function(
    file_path=file_name,
    new_model=True,
    num_epochs=train_cfg['num_epochs'],
    gen_epochs=train_cfg['gen_epochs'],
    batch_size=1024,
    train_size=train_cfg['train_size'],
    dropout=train_cfg['dropout'],
    validation=train_cfg['validation'],
    is_csv=train_cfg['is_csv'],
    rnn_layers=model_cfg['rnn_layers'],
    rnn_size=model_cfg['rnn_size'],
    rnn_bidirectional=model_cfg['rnn_bidirectional'],
    max_length=model_cfg['max_length'],
    dim_embeddings=100,
    word_level=model_cfg['word_level'])
# Out:
# Training new model w/ 3-layer, 128-cell Bidirectional LSTMs
# Training on 522,943 word sequences.
# Epoch 1/20
# 510/510 [==============================] - 51s 100ms/step - loss: 3.6781
# Epoch 2/20
# 510/510 [==============================] - 48s 94ms/step - loss: 3.0434
# Epoch 3/20
# 510/510 [==============================] - 48s 94ms/step - loss: 2.7159
# Epoch 4/20
# 510/510 [==============================] - 49s 96ms/step - loss: 2.4328
# Epoch 5/20
# 510/510 [==============================] - 48s 94ms/step - loss: 2.1686
# ####################
# Temperature: 0.2
# ####################
# < newline >
# i ' ve been thinking ' bout the bar < newline > i ' m not your average girl < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking ' bout the world of the world < newline >
# i ' ve been searching for so long < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world < newline >
# i ' ve been thinking ' bout you < newline >
# i ' ve been thinking about the things i ' ve been through < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world of the world < newline >
# i ' ve been thinking ' bout ya < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about the things i ' ve been through < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about the things i ' ve been through < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world < newline >
#
# < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking ' bout ya < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for a sign < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking ' bout ya ? < newline >
# i am a sailor , you know me ? < newline >
# i ' ve been around the world < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking ' bout the first time < newline >
# i was lost in the dark < newline >
# i ' ve been waiting for you < newline >
# i ' ve been
#
# < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout ya < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout you < newline >
# i ' ve been thinking ' bout the world of mine < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking ' bout the world < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about the things i ' ve been through < newline >
# i ' ve been thinking about the things i ' ve been through < newline >
# i ' ve been thinking ' bout you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' m a sucker for you < newline >
# i ' ve been thinking ' bout the world of the world < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about
#
# ####################
# Temperature: 0.5
# ####################
# > maybe i ' m not just one to be a woman < newline >
# i had a dream of my own true lover < newline >
# the world is sunlight < newline >
# i am the city < newline >
# i ' ve been around the world of the world < newline >
# on a hill far away from home < newline >
# i ' ve been thinking about you < newline >
# i know you like the thing < newline >
# i am the city lights < newline >
# you ' re so hot < newline >
# baby , baby < newline > you know that i can ' t < newline >
# i ' ve been waiting for a sign < newline >
# one day , one two three four < newline > wait wait wait wait < newline >
# i ' ll be home for you < newline >
# i ' m a rollercoaster < newline >
# i ' ll be home for christmas < newline >
# i ' ll be home for christmas < newline >
# i used to say " < newline >
# i ' ve been thinking about the things that we ' ve been through < newline >
# ( music & lyrics ) < newline > you wake up in the morning < newline > i ' m not just a fool < newline >
# i know you ' ve been acting so cold ( since i ' m feelin ' older < newline >
# i feel like a river , lost his way < newline >
# i ' ll be home to stay < newline >
# i '
#
#
#  i ' m sick of your heart < newline >
# i ' ve been here to fall < newline >
# i ' ll be home for you < newline >
# i ' ve been waiting for you < newline > i know you ' re not bad < newline > don ' t want to be my heart < newline >
# i took the picture in the dark lights < newline >
# i ' ve been thinking it all < newline >
# i walk along the city streets were inseparable < newline >
# i used to say < newline >
# i ' ve been waiting for you < newline >
# i ' ve been thinking about you < newline >
# i ' ve been waiting for you < newline > i could be dancin ' < newline >
# i ' ve been searching for so long < newline > i ' m not just one to be my last < newline >
# i ' ve been waiting for you < newline >
# i ' ve been here for a while < newline >
# i ' d like to save the world < newline >
# i ' ve been thinking about you < newline >
# i know you ' ve been acting crazy < newline > i ' m not your average girl < newline >
# i ' m not a saint , but not know < newline >
# i ' ve been around the world < newline >
# i ' ve been searchin ' for you < newline >
# i ' ve been searchin ' for a long way < newline >
# i ' ll be home for
#
# < newline >
# the world is fading out < newline >
# i ' m not your average girl < newline > i want to do it for a guy to give you < newline >
# you ' re the one for me < newline >
# you ' re the one for me < newline >
# i ' ve been searching for love < newline >
# i ' m gonna get you on the phone < newline >
# i ' ve been thinking ' bout ya < newline >
# i ' ve been counting my way < newline >
# you ' re my room , you ' re my obsession < newline > i got something new , don ' t care < newline >
# i was born in the country < newline >
# i ' m not the suspicious of things < newline >
# i guess i ' m a california one < newline >
# i ' m not the suspicious of things that i want to do < newline >
# you and i know that you ' re not all < newline >
# i guess there ' s something in the air . < newline >
# i think you ' re gonna be my sex , yeah < newline >
# i ' m not your average girl < newline >
# i believe in the world that she ' s in < newline >
# [ originally performed by foreigner ] < newline > i ' ve been searchin ' for too long to give to < newline >
# i ' ve been expecting my christmas < newline >
# [ chorus ] < newline > i love just to come
#
# ####################
# Temperature: 1.0
# ####################
# newline >
# its getting to me that you love me < newline > i ' ve been thinking about ya too many people . < newline >
# i feel sure did i feel < newline >
# [ verse 1 ] < newline > i may not get over now if you keeps me come alive . < newline >
# the way of our princess < newline > but every time i wait to rise and i put on my wings < newline >
# i said , " johnny ' on " < newline >
# is there a place where to be afraid for you < newline >
# they read , my soul , turned out the flame of trouble < newline >
# the room is no way they go through < newline > when i ' ve seen the dreams < newline > put on my head to the floor < newline >
# esta tarde por ah adiã³s < newline > entre tu comme un , les de < newline >
# des silencio , dans la < newline > it de mã­â­ bien < newline >
# en why , hoy la por qu , < newline > que he vuelto a caminar < newline >
# quise ocultar cada peu de mentir , < newline >
# nada de ti - gracias a cantar < newline > he thought a veces ago < newline > lost his heart around the ocean tides , the second < newline >
# we ' re gonna rise , we ' ll fall out of our hands , free again . . . . . . < newline > . . . . . < newline > energy < newline > destroy me
#
# > [ intro ] < newline > [ enrique iglesias ] < newline > somebody calls me darling somebody < newline >
# rock shut , heal , keep your lips ; did he ever try < newline > hold me , baby . . . < newline > you led a look back on me , < newline >
# i said yesterday < newline > so you fell or yes < newline >
# i believe in despair < newline > since the beginning of the state < newline > there took me a care < newline > why ' s your mind when the rules were right < newline >
# together < newline > every time you ' ve been acting home < newline > with a broken life , not under your eye < newline > you could barely breathe under my wings < newline > been crying in the world of mine < newline >
# 13 - past surprise < newline > my hair was on and so fine you are < newline > that ' s perfect for you < newline >
# i do what i like in the night < newline >
# i know you ' re gonna be lonely < newline >
# i couldn ' t sit and wait in the give you time < newline >
# we had plans to make a wish < newline >
# it ' s the hardest thing of < newline >
# ( van llegando / / thomas ) < days < newline > oh , so strange < newline > i ask her to know where i see < newline > for the pathway < newline > make me on your pants and for your story ? <
#
# seeing me to the sky < newline >
# don ' t care < newline >
# my heart is a foreigner < newline >
# take a bit of mmh to me < newline > oh nothing so you doing your mind , < newline > you will see an open sea ? < newline >
# you sheltered me from harm < newline coats < newline > any - who they do to fight and say what are you no going to know ? < newline > ' cause i know that i love him twice my heart < newline >
# beats , yakap , yakap now , . < newline > and a heart that is no other < newline >
# you had your best way , and what i think < newline >
# out the station in the sea of the city hand < newline > and it feels like yesterday < newline > in fading and weary ways < newline >
# i can remember that i can bear enough < newline >
# una y un beso ? < newline >
# wish i could hold you close < newline > it all started again < newline >
# don ' t sabes hard rain last before < newline >
# never trust this , woman never < newline > i like the room when you ' re feeling low , < newline > what goes around comes back alright ? < newline > and how ' d i find a girl or everywhere i come < newline >
# war is bein someone < newline > almost you ' ve never been more < newline >
# whatever cannot stop fighting < newline > and words could cut with your
#
# Epoch 6/20
# 510/510 [==============================] - 50s 97ms/step - loss: 1.9356
# Epoch 7/20
# 510/510 [==============================] - 50s 98ms/step - loss: 1.7380
# Epoch 8/20
# 510/510 [==============================] - 48s 94ms/step - loss: 1.5633
# Epoch 9/20
# 510/510 [==============================] - 49s 95ms/step - loss: 1.4165
# Epoch 10/20
# 510/510 [==============================] - 49s 96ms/step - loss: 1.2828
# ####################
# Temperature: 0.2
# ####################
# oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh ,
#
# newline > i ' m a california label < newline >
# i ' ve been thinking about the things that we ' ve been through < newline >
# i ' m a mess < newline >
# i can ' t help but i can ' t help it . . . < newline >
# i ' m a mess , such a wreck : < newline >
# a dream of the dance floor < newline >
# i ' ve been thinking about the things that we ' ve been through < newline >
# i ' m a mess , such a wreck by a town < newline >
# i had a love < newline > and i ' ll be scared and i ' ll be here forever < newline >
# i ' m a mess , such a wreck by a side < newline >
# i ' m a mess , such a wreck by a side < newline >
# i ' m a mess , such a wreck < newline >
# i ' m a mess , such a wreck : < newline >
# here we go < newline > here we are going on < newline >
# i ' m a mess , such a wreck < newline >
# it ' s a long , long journey < newline >
# i ' m a mess , such a wreck < newline >
# i ' m a mess , such a wreck < newline >
# it ' s been five months since you went away < newline > left without a word < newline >
# i ' m a mess , such a wreck < newline >
# it
#
# oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh ,
#
# ####################
# Temperature: 0.5
# ####################
# viens - tu , tu ne jamais je te pas < newline >
# ne change rien dire < newline > j ' avais encore peur hier < newline >
# i ' ve been alone so long , i ' m alone < newline >
# i can feel it coming , like a work or at < newline > we were all alone < newline >
# i ' m in love with the irish accent to your story < newline >
# [ ] < newline > beoreutcheoreom < newline > perfume < newline > cigarettes < newline >
# i ' m a mess , such a wreck in the five , < newline >
# i thought i ' d be leaving < newline >
# the snow is snowing , the wind is blowing < newline > the wind blows , the things that never stop < newline >
# i can feel your arms < newline >
# i ' m so into you < newline >
# i ' m not looking for a man < newline >
# i ' ve been so many places in my life < newline >
# i don ' t know where you ' re plugging in < newline >
# it was the third of september . < newline > that day has fallen , < newline > i ' m a lion with the hair < newline >
# i ' m not your stepping stone < newline > and your shadow pulled me down < newline >
# i was on the walk home < newline >
# i was a hot mess < newline >
# you ' re scared of watching from your eyes < newline >
# i can
#
# newline > i don ' t know what to do < newline >
# i ' m a mess , such a wreck by a town < newline > and when the sun turns to light < newline >
# i ' ve been so many places in my life and time < newline >
# baby , i ' m so into you < newline >
# i ' m a mess in the afternoon < newline >
# i can ' t take it away < newline >
# i like to move my body to move < newline >
# i am the night < newline >
# i ' m so into you < newline >
# i can ' t sit here , < newline >
# i ' m a mess , such a wreck < newline >
# it ' s a breathless night < newline > there ' s a land that i heard < newline >
# i was a lover , a leader of me < newline > i ' m just a girl < newline > a girl in the light , she ' s all set , < newline >
# i see the sun rise , feel the fire < newline > the street i love the world < newline >
# i ' m a bird without a sky < newline >
# just a day , way home < newline >
# i ' m so into you < newline > i can ' t forget that i can ' t live without you < newline > i ' ll be your sunday - morning < newline >
# i ' m writin ' you a liar , man < newline >
# i '
#
# ga up ( yo ) < newline >
# ay , ay mama ( ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay ( ay , ay , ay , ay , ay , ay , ay , ay , ay , ay , ay mama ( ay ) < newline > ( ay ) < newline > ( ay ) < newline > ( ay ) < newline > ( ay ) < newline > oh , hey , < newline >
# throwing rainbows at your feet < newline >
# she ' s like a medicine to a sick mind < newline > we steppin out to school < newline >
# i ' m always thinking about you < newline >
# i know you like to wear a dressing up in the morning < newline >
# i ' m gonna make your fear < newline >
# i want to be the lover < newline >
# i ' m telling you i ' ve ever been < newline >
# you ' ve got a cute way < newline >
# i ' m getting dizzy here < newline > you ' re not the one i need you < newline >
# i ' m a mess , such a wreck : < newline >
#
#
# ####################
# Temperature: 1.0
# ####################
# >
# shadows falling , baby , we stand alone < newline > guess my gonna hold you tight < newline > don ' t wanna be alone < newline > when you wake up all breath < newline > on mine , the night makes my babe < newline > your eyes are burning like gold < newline >
# down less bell < newline > just one day , one day , easy against a heart of light < newline > a man to break down with the . < newline >
# my baby ' s mad is the real thing , baby it ' s the last time < newline > the an old world turned and i am < newline > i like heaven that i can be < newline >
# heart wish they rose < newline >
# going round my heart again < newline >
# d ' oã¹ dans le me ' peu respect dolphins < newline >
# there was a time , now there was a smile < newline > who could ever hurt you < newline > ever since i saw again < newline > from falling a broken heart < newline > and pray < newline >
# don ' t know much about your life all my life in syrup < newline > she stood with a , < newline >
# i know it ' s all this town < newline > the rhythm is green < newline >
# fire , my boat < newline > can ' t take my hand away < newline > i pray for me huh < newline > cause who ' s what they want to be right . < newline >
# i met one night in
#
# o fue mi amor , < newline > habr melancola < newline > yo s que habr dolor < newline >
# quiero perderme en tu < newline > dos pena < newline > bergman que tu lo que me < newline >
# perfection < newline > i can find you when i ' m for a that out < newline >
# i ' m into something playing against the night < newline > i pray for a love < newline >
# so many twenty of this devil < newline > of reach of lost < newline > you know i would < newline >
# caught in front this ever since i saw you < newline > i knew all the week i looked at you one < newline > in a world where you go < newline > the way you go see < newline >
# van longtemps , que tu es sweetness < newline >
# ahora que te vas , , se te muy . < newline >
# tan triste pick a la < newline > per ogni un < newline >
# elle est dans ma dans l ' elle se , < newline > que pour la paz < newline >
# no , use , imagination yeah < newline > i ' ve been working all systems go out won < newline > when your heart ' s a mess < newline >
# i woke up this morning < newline > searchin ' for her man the other < newline >
# i ' ve been alone on my own < newline >
# here it is just like it < newline >
# i ' ve driven round round in the red light < newline >
#
# kaze no to your side . < newline > i felt myself , ill be in here without you < newline > i ' ll tell you what you mean , when i am with you < newline >
# an old old day , my people were my my very weighed < newline >
# woke up your head baby < newline > staring at me the place to look in a place < newline >
# animal i ' ve been down the street < newline > since i was a child < newline > then a few and three in this bed < newline >
# i ' m a mess < newline > that ' s what they mean with me < newline > pray , pray < newline > mmm , < newline > it ' s getting 2 < newline > it ' s a figure of speech < newline >
# wake up you make a wish ring ? ) < newline >
# another bigbang - light < newline >
# woke up this morning < newline > call the shore < newline >
# i got something new , < newline >
# don ' t call me now , so i don ' t why < newline >
# darlin ' i got no money < newline > tattoos is a god and a a few < newline >
# [ chorus ] < newline > let ' s take this over ? < newline > things you do ? < newline > everybody in the life so easily < newline >
# oh i cannot find a way < newline >
# i vit alone awake , getting in my bed < newline >
# sometimes , that you
#
# Epoch 11/20
# 510/510 [==============================] - 47s 93ms/step - loss: 1.1676
# Epoch 12/20
# 510/510 [==============================] - 50s 98ms/step - loss: 1.0644
# Epoch 13/20
# 510/510 [==============================] - 50s 97ms/step - loss: 0.9729
# Epoch 14/20
# 510/510 [==============================] - 48s 94ms/step - loss: 0.8867
# Epoch 15/20
# 510/510 [==============================] - 49s 96ms/step - loss: 0.8139
# ####################
# Temperature: 0.2
# ####################
# < newline > see you the night , you are < newline >
# i ' ve got a secret i wanna know < newline > i ' m not the one to look up at the time < newline >
# i ' m not a perfect person . < newline >
# i ' m not , i ' m a little too much too weak , < newline >
# i ' m not a perfect person . < newline >
# i ' m a , a diva , hey , yeah < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re so scared , and you ' re not all < newline >
# you ' re so scared of falling in love . < newline >
# i ' m not a perfect person . < newline >
# i ' m not , i ' m through < newline >
# i ' ve got a secret i wanna know < newline >
# i know you think i ' m gonna have your on my own < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you ' re
#
# < newline > see ' most of your life < newline >
# i don ' t wanna be that city boy < newline >
# i ' m not , i ' m just telling the truth < newline >
# we ' re gonna run , gonna run , gonna save you < newline >
# you ' re so good to me , baby < newline >
# this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > this is my dedication . < newline > i ' m just a girl with a smoking < newline >
# in a perfect world , people everywhere < newline >
# there ' s a time , when we all choose , < newline > to either quit or follow through . < newline >
# i ' m not , i ' m a world wide woman < newline > you ' re the one i need < newline >
# i don ' t wanna be that city boy < newline >
# i ' m not , i ' m a world wide woman < newline > you ' re the one i need < newline >
# there is something
#
# < newline >
# i ' m not a casanova < newline >
# i ' ve got a secret i wanna know < newline >
# i ' m not , i ' m through < newline >
# i ' ve been giving up for you < newline >
# i ' m not , i ' m just telling the truth < newline >
# we ' re gonna run , gonna run , gonna save you < newline >
# do you know where you ' re going < newline >
# oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh , oh ,
#
# ####################
# Temperature: 0.5
# ####################
# la luna gracias a ti < newline > estoy de ti y en ti < newline >
# i ' m , i ' m through < newline >
# all the things i want to you see < newline >
# i ' m moving on up the right side < newline >
# you know i ' m the kind of guy that does a 9 to 5 < newline >
# [ verse 1 ] < newline > i know you think i ' m gonna be < newline >
# i don ' t wanna be leaving ? < newline >
# i ' m not , i ' m through < newline >
# oh , you built me like < newline >
# how many times have you told me < newline > tell me to forgive me < newline > you smiled and left me < newline > you ' re my kind < newline >
# i ' ve got a secret , been hiding oh , oh oh < newline > oh < newline >
# [ chorus ] < newline > do you feel my heart beating < newline >
# oh there ' s something in her < newline > and it ' s the middle of the day < newline >
# i ' m in a deep place < newline > i ' m falling in love < newline > it will be forever < newline > or i ' ll never fall in love < newline >
# bad blood . < newline > i walk out , in every way < newline >
# we sailed over the room < newline >
# i fell in a fall < newline > with my heart to
#
# < newline > see i was a fool < newline >
# you ' re so scared of falling , i ' m alone < newline >
# i ' m not the easiest now < newline >
# it took a while to < newline > and its the only time for this < newline >
# why you look so sad and more and < newline >
# i ' ll be home for christmas < newline > you can count on me < newline >
# do you know where you ' re going < newline > but i don ' t know why < newline > i ' m surviving every lonely day < newline > when there ' s got to be < newline >
# well , you can wear a new day < newline >
# i ' m not , yeah i ' m ready , yes i do for you < newline >
# you ' re the one i wanna talk about , talk about < newline >
# you and i once shared love < newline > you don ' t know me < newline > i ' ll be the sweetest thing you ever knew < newline >
# you ' re the one i wanna talk about . < newline >
# , oh oh , oh , oh , oh , oh , oh , oh < newline > oh , oh , oh < newline >
# what if only i was you < newline > i was supposed to tell you this < newline >
# in my head , you look at me that i ' m lost < newline >
# let ' s go explore < newline > boom hand on
#
# well , you can wear those like those llamas or stupid < newline >
# una noche con luna llena < newline >
# un mundo sight < newline > la se ha ah ah < newline >
# i ' m not that someone who ' s got me gotta be doo doo doo < newline >
# when will i < newline > it ' s a drag to leave my car < newline >
# as i look at you < newline >
# chestnuts roasting on an open fire < newline > jack frost nipping at your nose < newline >
# it feels like i ' m lost < newline >
# i can ' t believe you ' re telling me lies < newline >
# i was sad there < newline > and i ' m still in the sound < newline >
# let me take you on a trip < newline > leaving in the name of love < newline > before you break my heart , < newline >
# don ' t know you < newline > that ' s what i ' m thinking < newline >
# i ' ve got a secret < newline > and i feel like i ' ve been wanting you all my life < newline >
# it ' s just like this , mr . . < newline >
# sigo ( a - go get a move ) < newline >
# where did the sunshine , why you at me ? < newline > and what do you want ? < newline >
# ooh - ooh < newline > ah - ah - ah - ah - ah < newline > ah - ah - ah -
#
# ####################
# Temperature: 1.0
# ####################
# < newline >
# a life ' s a oooo < newline >
# every day i gotta go < newline >
# so many girls in here , where do i begin ? < newline > you were to me < newline >
# i remember back in the a cloud , < newline >
# oh , her eyes open your eyes < newline >
# hey there lady < newline > i ' ve cried and found out my friend < newline > where ' s up or blue < newline >
# point in pride and lights out the dirt < newline >
# don ' t shed a tear for me < newline > oh , oh , hey , dear and my wonderful < newline > it take things to work for < newline >
# you ' ve got it bad < newline > so i got you with a girl ? < newline >
# forget , have it been working hard < newline > children who stand < newline > such a fool to make a sacrifice < newline >
# jesus ' ll be a fool to let you know some day , < newline > that ' s where i was are < newline >
# i ' m lost in this pain in space < newline >
# give you one touch < newline >
# you ' re living some kind < newline > and i need a thousand reasons to try < newline > if the one before me gets you inside < newline > was i your only little girl < newline >
# yeah yeah yeah yeah yeah yeah < newline > yeah yeah yeah yeah < newline > sittin ' alone wishin '
#
# si tãº supieras < newline > que tu recuerdo me acaricia como el viento < newline >
# yo no sã© < newline > por quã© , no puedo olvidar lo que fue < newline >
# si tãº supieras < newline > que tu recuerdo me acaricia como el viento < newline >
# yo sã© < newline > der catch ya chick to die < newline >
# oh you ` re shaking in the morning and put ' over < newline >
# nothing ' s gonna harm you < newline > wanna feel this way < newline > did it want to be < newline >
# drifting in the tide < newline >
# another dream from the ground < newline >
# not too soon to cry < newline >
# see you walking my eyes < newline >
# through a - - white christmas , all waited in - - oh yeah < newline >
# counting stars all in the of her eyes < newline >
# laughing at the edge of , < newline >
# there is someone < newline > i ' m doing everything to say < newline >
# gotta tell you < newline > light < newline > [ verse 1 ] < newline > look into my eyes < newline >
# like a mean ain ' t breathe < newline >
# from this child < newline > the days where we used to be when we first met ( this a well the time ) < newline > radio silence < newline >
# some people say who i never see < newline >
# say my name , say my name < newline > ' cause tonight is so night <
#
# " . " , i like a fool i can find < newline > and how can change the world ? < newline > do you feel , do you feel its re not whole < newline > it ' s there in the night < newline > he sits down here on my body < newline > take me caught , take me away < newline > baby , let me check , i ' m gonna lose my mind < newline >
# i don ' t wanna leave here without you < newline >
# let looking in love that today comes < newline >
# i got a feeling in your way < newline > do - - - - - - i - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - chante - longs to feel the day < newline > like the sun was going down < newline > and do you think it ' s better , < newline > i ' m losing < newline >
# board the funk in today < newline > and it feels < newline > some children be the same , no dirt , all are you changing ? < newline >
# roll with tears and them like fly < newline >
# if they say that something , everything would break my
#
# Epoch 16/20
# 510/510 [==============================] - 48s 95ms/step - loss: 0.7471
# Epoch 17/20
# 510/510 [==============================] - 48s 94ms/step - loss: 0.6880
# Epoch 18/20
# 510/510 [==============================] - 49s 97ms/step - loss: 0.6371
# Epoch 19/20
# 510/510 [==============================] - 48s 95ms/step - loss: 0.5916
# Epoch 20/20
# 510/510 [==============================] - 49s 96ms/step - loss: 0.5595
# ####################
# Temperature: 0.2
# ####################
# kiss ( ha ) < newline > uh , uh , uh , uh < newline > yo , yo ( yo yo yo ) < newline > [ ciara ] < newline > uh uh < newline > uh - huh , uh - oh < newline > uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh < newline > uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh < newline > uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh < newline > uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh - oh , uh
#
# < newline > see i was a fool < newline >
# you know i ' m the kind of guy that does a nine to five < newline >
# ooh baby , oh baby , baby < newline > oh baby , baby < newline > oh baby , baby , how was i supposed to know < newline >
# [ repeat 2x ] < newline > shake it up < newline > shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up , shake it up ,
#
# < newline > see i was a fool < newline >
# you know i ' m the kind of guy that does a nine to five < newline >
# ooh baby , oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby , how was i supposed to know < newline >
# you know i ' m the kind of guy that does a nine to five < newline >
# ooh baby , oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby < newline > oh baby , baby <
#
# ####################
# Temperature: 0.5
# ####################
# kiss ( ha ) < newline > hey ( yeah ) [ x4 ] < newline > girls ! < newline > i don ' t mean to bother you , i see you with your girlfriends < newline >
# how could anyone ever change the things < newline >
# i ' ve got a secret i can ' t keep < newline >
# it ' s a long road and it up . . . < newline >
# i ' m your tamagotchi . < newline > so i used to tell < newline >
# you ' ve got me thinkin ' ' bout tomorrow . < newline >
# you ' re my miss right , miss right < newline > if i ain ' t got nothing , i got a lot of money < newline >
# i ' m a , a forty - five , < newline > i ' ve got to go away < newline >
# mary , did you know < newline >
# the moment i wake up < newline > before i put on my makeup < newline >
# dearest darling i was looking for the circus < newline >
# i don ' t know , i ' m not the type < newline > to say one thing and do another < newline >
# i ' m a fool to want you < newline > i ' m gonna get to know you better < newline >
# i just want to ready , i ' m the one < newline >
# you made me believe in magic < newline > i ' m in love with everything that breaks < newline >
# i can ' t
#
# < newline > feels like i ' m falling to get myself < newline >
# yeah , i ' m a taurus < newline > they say that we ' re patient < newline >
# don ' t know you < newline > that ' s what you get when you lost ? < newline >
# i can be tough < newline > i can be strong < newline >
# i know that it ' s late < newline > when i close my eyes < newline > i hide behind the blackened lies < newline >
# machines are racing < newline > they ' re lonely in the night < newline >
# mary ' s boy child jesus christ , was born on christmas day . < newline >
# sunny , yesterday my life was filled with rain < newline > sunny , you smiled at me and really eased the pain < newline >
# by the rivers of babylon , there we sat down < newline > ye - eah we wept , when we remembered zion < newline >
# see the stars come joining down from the sky < newline >
# youre away from me < newline >
# when i look into your sad eyes < newline >
# i ' ve got a friend and she ' s a beauty < newline > where your friends from the day < newline > when you got rain on me baby please < newline >
# i ' m not afraid to say it < newline >
# it ' s a working world i can do < newline >
# turn it up < newline > i ' ll dance till you come and away <
#
# < newline >
# i ' ll be home for christmas < newline > no , i ' m into something < newline >
# i ' m a fool to want you < newline > i ' m thinking one day < newline >
# you ' re the light , you ' re the night < newline > i ' m telling you lies my name < newline >
# girls , for tonight < newline >
# i ' m dreaming of a white christmas < newline > just like the ones i used to know < newline >
# you know i ' m the kind of guy that does a nine to five ? < newline >
# the of my head is your ground ? < newline >
# i am the of my fortunes < newline > i ' ve got you under my skin < newline > i ' m falling under < newline > a girl like me < newline >
# outrageous , when i move my body < newline > outrageous , when i ' m at a party < newline >
# so curious < newline > you ' re the one i need < newline >
# i ' ve been waiting for so long < newline >
# i ' m gonna do your ) < newline >
# my my < newline > at waterloo napoleon did surrender < newline > oh yeah < newline > ( representing bk ) but , tell me what you do . < newline >
# there ' s a fire , there ' s a fire < newline > an got a letter in my heart < newline >
# i ' m a fool to want you
#
# ####################
# Temperature: 1.0
# ####################
# kiss ( ha ) < newline > last for you will do < newline >
# it ' s a working thing to sail away < newline > i ' m leaving in things this time your life have no one < newline > no one knows what time ? < newline > why you lookin ' so down ? < newline > when i can ' t see the hero of < newline > the night ' s the time for girl ' s an old day . < newline > i gotta get to you . < newline >
# i should of met with were the moment < newline >
# they came from the hills for the night - silver ' ' < newline >
# listen baby can you take me terre , j ' yo < newline > y ' all < newline > ayo stanley you ) < newline >
# i ' ll hear you live < newline >
# < newline > don ' t care about money < newline >
# every now on the radio < newline >
# every solo - . paul ' s ' , for the for that , i ' m think on you < newline > don ' t pretend you feel that ( you know the anymore < newline >
# first you think you are not in love < newline > one time before the of every christmas it would take you on ? < newline >
# estoy enamorado de tu knowing para ternura < newline >
# 1 : < newline > somebody asked me how i knew < newline > tear down your face , baby < newline >
# when i look in your eyes i see
#
# newline >
# quiero te vas , con tus besos me < newline >
# dime princesa de hielo dnde vas < newline > sin saber a dnde voy en realidad < newline >
# we work , we are to it ( yeah ) < newline >
# can ' t take the cold days < newline > and these are your arms around me < newline > fragments of peace afford from the moment < newline > we ' re in this together < newline >
# i believe in between love and how am i love < newline > whether i ' d be the one , yeah i ' m a now , i ' m too big again . . < newline >
# our whole universe was in a hot dense state , < newline > then nearly fourteen billion years ago expansion started . wait . . . < newline > maybe i never let you in my heart < newline >
# i ' m not leaving ( you ' re both gonna miss that < newline >
# la la la la , lalalala la , la la la < newline > la la la la la la < newline >
# stop , give me a little love < newline > see the way her take of your heart while really want to be < newline >
# i saw you chestnuts along the dark wedding room < newline > encore , you know why we ain ' t it like me < newline >
# deep in the jungle , < newline > in the war , of the pain < newline >
# over me , won ' t you set your monkey free ? < newline >
#
# kiss < newline >
# chorus : < newline > your body ' s like a rollercoaster < newline >
# we deep ( yeh suh ! ) < newline > we throw , we blow ( uh huh yea suh ! ) < newline >
# sometimes being be with you < newline >
# oh , my love it makes me sad . < newline > please me your time < newline >
# you said you ' d never love < newline > ay ' cause that ' s a cat you ' re a crawling down and she ' s wouldn ' t go < newline > so < newline > you won ' t be there if they try to get it to work it , i don ' t do it , first changes can change ? < newline >
# down and up , down this street < newline > i don ' t miss you no more time , no < newline > to fight it all with my love life < newline > calling for the streets < newline > only when their eyes fall in deep . < newline >
# we ' ve somehow spent like a high school dance on the rise < newline > get hurt the pretty < newline >
# ooh ooh ooh < newline > you were the tree and i was the apple < newline >
# i opened the door to your head < newline >
# hi everybody , where its the , how i just sit here by < newline >
# my eyes they run dry town < newline >
# rain , rain on the land < newline >
# das cosas del amor < newline >

# %% [markdown]
# You can download a large amount of generated text from your model with the cell below! Rerun the cell as many times as you want for even more text!

# %%
# this temperature schedule cycles between 1 very unexpected token, 1 unexpected token, 2 expected tokens, repeat.
# changing the temperature schedule can result in wildly different output!
temperature = [5.0, 2.0, 1.0, 0.5]   
prefix = None   # if you want each generated text to start with a given seed text

if train_cfg['line_delimited']:
  n = 1000
  max_gen_length = 60 if model_cfg['word_level'] else 300
else:
  n = 1
  max_gen_length = 2000 if model_cfg['word_level'] else 10000
  
timestring = datetime.now().strftime('%Y%m%d_%H%M%S')
gen_file = '{}_gentext_{}.txt'.format(model_name, timestring)

textgen.generate_to_file(gen_file,
                         temperature=temperature,
                         prefix=prefix,
                         n=n,
                         max_gen_length=max_gen_length)
files.download(gen_file)

# %% [markdown]
# You can download the weights and configuration files in the cell below, allowing you recreate the model on your own computer!

# %%
files.download('{}_weights.hdf5'.format(model_name))
files.download('{}_vocab.json'.format(model_name))
files.download('{}_config.json'.format(model_name))

# %% [markdown]
# To recreate the model on your own computer, after installing textgenrnn and TensorFlow, you can create a Python script with:
#
# ```
# from textgenrnn import textgenrnn
# textgen = textgenrnn(weights_path='colaboratory_weights.hdf5',
#                        vocab_path='colaboratory_vocab.json',
#                        config_path='colaboratory_config.json')
#
# textgen.generate_samples(max_gen_length=1000)
# textgen.generate_to_file('textgenrnn_texts.txt', max_gen_length=1000)
# ```
#
# Have fun with your new model! :)

# %% [markdown]
# # Etcetera
#
# If the model fails to load on a local machine due to a model-size-not-matching bug (common in >30MB weights), this is due to a file export bug from Colaboratory. To work around this issue, save the weights to Google Drive with the two cells below and download from there.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
uploaded = drive.CreateFile({'title': '{}_weights.hdf5'.format(model_name)})
uploaded.SetContentFile('{}_weights.hdf5'.format(model_name))
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1b6T6M32YnXs-c0NB-PEi6MhAdCuG7RHy

# %% [markdown]
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
